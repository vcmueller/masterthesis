# %% [markdown]
# # Models for ranking
#
# The word embedding model is used for computing the similarity score between roles and people, based on skills and interests.
# A score is calculated from each Word Mover's Distance computed and a final score is calculated as a weighted combination of all scores.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
from gensim.models import Word2Vec
import numpy as np

# %% [markdown]
# ## Enter Role Requirements

# %%
# Get the role requirements
role_id = 12
#role_skills = ['C#', 'Kotlin', 'Python', 'SQL', 'PostgreSQL', '.NET', 'Apache Kafka', 'Pandas', 'Docker', 'Kubernetes']
#role_experience = 'Associate'

# Get the role from the collected data from the survey
role = pd.read_csv(filepath_or_buffer="../2-data/survey_roles.csv", sep=",", encoding="latin1")
role = role[role['id']==role_id]
role_skills = role['skills'].values[0].split(';')
role_experience = role['explevel'].values[0]

print(role_id)
print(role_skills)
print(role_experience)
# Out:
# 12
# ['Bash/Shell', 'PowerShell', 'SQL', 'Microsoft SQL Server', 'Microsoft Azure', '.NET', 'Apache Spark', 'Ansible', 'Docker', 'Terraform']
# Associate

# %% [markdown]
# # Load Employees Dataset

# %%
# Read the employees dataset - from the data entered in the survey
df_people = pd.read_csv(filepath_or_buffer="../2-data/survey_people.csv", sep=",", encoding="latin1")

# Tokenize the skills
df_people['skills'] = df_people['skills'].apply(lambda x: x.split(';'))

# Get only required columns
df_people = df_people[['id', 'skills', 'skills-want', 'YearsCodePro']]
df_people
# Out:
#     id                                             skills  \
# 0    1  [Java, JavaScript, Python, SQL, MySQL, SQLite,...
# 1    2  [C++, HTML/CSS, Java, JavaScript, PHP, Python,...
# 2    3  [C++, HTML/CSS, Java, PHP, Python, SQL, MariaD...
# 3    4  [HTML/CSS, JavaScript, Kotlin, TypeScript, AWS...
# 4    5  [C#, Java, JavaScript, PHP, PowerShell, Python...
# 5    6  [MATLAB, Python, R, SQL, Swift, Cassandra, Cou...
# 6    7  [Bash/Shell, PowerShell, Python, Scala, SQL, M...
# 7    8  [Bash/Shell, C#, C++, Java, PowerShell, Python...
# 8    9  [Assembly, Bash/Shell, C#, C++, Go, HTML/CSS, ...
# 9   10  [MATLAB, Python, R, SQL, Microsoft SQL Server,...
# 10  11  [Python, SQL, Microsoft SQL Server, MySQL, Mic...
# 11  12  [Assembly, Bash/Shell, C, C#, C++, HTML/CSS, J...
# 12  13  [Python, SQL, Microsoft SQL Server, MySQL, Mic...
# 13  14  [Python, SQL, Microsoft SQL Server, MySQL, ASP...
# 14  15  [Go, Java, JavaScript, MySQL, PostgreSQL, Goog...
# 15  16  [Bash/Shell, JavaScript, Python, SQL, DynamoDB...
# 16  17  [Bash/Shell, C#, C++, HTML/CSS, JavaScript, PH...
# 17  18  [C, Go, HTML/CSS, Java, JavaScript, Kotlin, Lu...
# 18  19  [MATLAB, Python, SQL, Microsoft SQL Server, Go...
#
#                                           skills-want  YearsCodePro
# 0                          Dart;Java;SQL;MySQL;SQLite           3.0
# 1   HTML/CSS;JavaScript;TypeScript;AWS;Firebase;Go...           4.0
# 2          Python;MySQL;SQLite;Unity 3D;Unreal Engine           4.0
# 3   HTML/CSS;JavaScript;TypeScript;AWS;Firebase;An...           2.0
# 4   Python;R;SQL;Microsoft SQL Server;MySQL;Oracle...           9.0
# 5   Python;Microsoft SQL Server;MongoDB;Neo4j;AWS;...           1.0
# 6   Python;R;Scala;Microsoft SQL Server;MongoDB;Ne...          12.0
# 7   C#;Python;SQL;Cassandra;MariaDB;Microsoft SQL ...           6.0
# 8   C#;Go;HTML/CSS;Java;JavaScript;PowerShell;Pyth...           0.0
# 9   C++;Python;Scala;DynamoDB;MongoDB;MySQL;Oracle...           1.5
# 10  Python;SQL;Microsoft SQL Server;MySQL;PostgreS...           2.0
# 11  C++;Python;MySQL;Microsoft Azure;Keras;NumPy;Q...           5.0
# 12  Python;Microsoft SQL Server;MySQL;Microsoft Az...           5.0
# 13      R;DynamoDB;MongoDB;SQLite;AWS;Microsoft Azure           4.0
# 14  Java;TypeScript;DynamoDB;Microsoft SQL Server;...           6.0
# 15  Kotlin;Ruby;Rust;Redis;Google Cloud;Django;Fla...          11.0
# 16  Bash/Shell;C#;JavaScript;PowerShell;SQL;TypeSc...          10.0
# 17  C#;HTML/CSS;JavaScript;Python;Rust;TypeScript;...           2.0
# 18                                SQL;Microsoft Azure           2.0

# %% [markdown]
# # Load Word Embedding Model

# %%
model = Word2Vec.load("../3-word_embedding/model-w2vcombinedfiltered")

# %% [markdown]
# # Compute Similarity Scores

# %%
# Scaler to normalize scores
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %% [markdown]
# ## Score from Skills

# %%
# Calculate the distance between each person's skills and the role skills
similarity_scores = []
for skills in df_people['skills']:
    similarity_scores.append(model.wv.wmdistance(role_skills, skills))

# Add the dissimilarity score to each role
df_people['similarity_score_skills'] = similarity_scores

# Get the highest distance before inf
df_temp = df_people.loc[(df_people['similarity_score_skills'] < np.inf)]
max_score = df_temp['similarity_score_skills'].max()
print(max_score)

# Remove rows where the score is inf - meaning there is no similarity
df_people['similarity_score_skills'] = df_people['similarity_score_skills'].replace(np.inf, max_score)

# Normalize scores and convert distance to similarity -> 0 = more dissimilar, 1 = more similar
df_people['similarity_score_skills'] = 1 - scaler.fit_transform(df_people[['similarity_score_skills']])

df_people
# Out:
# 0.6594705569789168
#     id                                             skills  \
# 0    1  [Java, JavaScript, Python, SQL, MySQL, SQLite,...
# 1    2  [C++, HTML/CSS, Java, JavaScript, PHP, Python,...
# 2    3  [C++, HTML/CSS, Java, PHP, Python, SQL, MariaD...
# 3    4  [HTML/CSS, JavaScript, Kotlin, TypeScript, AWS...
# 4    5  [C#, Java, JavaScript, PHP, PowerShell, Python...
# 5    6  [MATLAB, Python, R, SQL, Swift, Cassandra, Cou...
# 6    7  [Bash/Shell, PowerShell, Python, Scala, SQL, M...
# 7    8  [Bash/Shell, C#, C++, Java, PowerShell, Python...
# 8    9  [Assembly, Bash/Shell, C#, C++, Go, HTML/CSS, ...
# 9   10  [MATLAB, Python, R, SQL, Microsoft SQL Server,...
# 10  11  [Python, SQL, Microsoft SQL Server, MySQL, Mic...
# 11  12  [Assembly, Bash/Shell, C, C#, C++, HTML/CSS, J...
# 12  13  [Python, SQL, Microsoft SQL Server, MySQL, Mic...
# 13  14  [Python, SQL, Microsoft SQL Server, MySQL, ASP...
# 14  15  [Go, Java, JavaScript, MySQL, PostgreSQL, Goog...
# 15  16  [Bash/Shell, JavaScript, Python, SQL, DynamoDB...
# 16  17  [Bash/Shell, C#, C++, HTML/CSS, JavaScript, PH...
# 17  18  [C, Go, HTML/CSS, Java, JavaScript, Kotlin, Lu...
# 18  19  [MATLAB, Python, SQL, Microsoft SQL Server, Go...
#
#                                           skills-want  YearsCodePro  \
# 0                          Dart;Java;SQL;MySQL;SQLite           3.0
# 1   HTML/CSS;JavaScript;TypeScript;AWS;Firebase;Go...           4.0
# 2          Python;MySQL;SQLite;Unity 3D;Unreal Engine           4.0
# 3   HTML/CSS;JavaScript;TypeScript;AWS;Firebase;An...           2.0
# 4   Python;R;SQL;Microsoft SQL Server;MySQL;Oracle...           9.0
# 5   Python;Microsoft SQL Server;MongoDB;Neo4j;AWS;...           1.0
# 6   Python;R;Scala;Microsoft SQL Server;MongoDB;Ne...          12.0
# 7   C#;Python;SQL;Cassandra;MariaDB;Microsoft SQL ...           6.0
# 8   C#;Go;HTML/CSS;Java;JavaScript;PowerShell;Pyth...           0.0
# 9   C++;Python;Scala;DynamoDB;MongoDB;MySQL;Oracle...           1.5
# 10  Python;SQL;Microsoft SQL Server;MySQL;PostgreS...           2.0
# 11  C++;Python;MySQL;Microsoft Azure;Keras;NumPy;Q...           5.0
# 12  Python;Microsoft SQL Server;MySQL;Microsoft Az...           5.0
# 13      R;DynamoDB;MongoDB;SQLite;AWS;Microsoft Azure           4.0
# 14  Java;TypeScript;DynamoDB;Microsoft SQL Server;...           6.0
# 15  Kotlin;Ruby;Rust;Redis;Google Cloud;Django;Fla...          11.0
# 16  Bash/Shell;C#;JavaScript;PowerShell;SQL;TypeSc...          10.0
# 17  C#;HTML/CSS;JavaScript;Python;Rust;TypeScript;...           2.0
# 18                                SQL;Microsoft Azure           2.0
#
#     similarity_score_skills
# 0                  0.116732
# 1                  0.000000
# 2                  0.043909
# 3                  0.280536
# 4                  0.526111
# 5                  0.480727
# 6                  0.682146
# 7                  0.572735
# 8                  0.407636
# 9                  1.000000
# 10                 0.908212
# 11                 0.409159
# 12                 0.715809
# 13                 0.618861
# 14                 0.177790
# 15                 0.638209
# 16                 0.625730
# 17                 0.312888
# 18                 0.606783

# %% [markdown]
# ## Score from Interests

# %%
# Tokenize the skills
df_people['skills-want'] = df_people['skills-want'].apply(lambda x: x.split(';'))

# Calculate the similarity between each person's skills and the role skills
similarity_scores = []
for skills in df_people['skills-want']:
    similarity_scores.append(model.wv.wmdistance(role_skills, skills))

# Add the similarity scores to each role
df_people['similarity_score_interests'] = similarity_scores

# Get the highest distance before inf
df_temp = df_people.loc[(df_people['similarity_score_interests'] < np.inf)]
max_score = df_temp['similarity_score_interests'].max()
print(max_score)

# Remove rows where the score is inf - meaning there is no similarity
df_people['similarity_score_interests'] = df_people['similarity_score_interests'].replace(np.inf, max_score)

# Normalize scores and convert distance to similarity - 0 = more dissimilar, 1 = more similar
df_people['similarity_score_interests'] =  1 - scaler.fit_transform(df_people[['similarity_score_interests']])

df_people
# Out:
# 0.6779650249471589
#     id                                             skills  \
# 0    1  [Java, JavaScript, Python, SQL, MySQL, SQLite,...
# 1    2  [C++, HTML/CSS, Java, JavaScript, PHP, Python,...
# 2    3  [C++, HTML/CSS, Java, PHP, Python, SQL, MariaD...
# 3    4  [HTML/CSS, JavaScript, Kotlin, TypeScript, AWS...
# 4    5  [C#, Java, JavaScript, PHP, PowerShell, Python...
# 5    6  [MATLAB, Python, R, SQL, Swift, Cassandra, Cou...
# 6    7  [Bash/Shell, PowerShell, Python, Scala, SQL, M...
# 7    8  [Bash/Shell, C#, C++, Java, PowerShell, Python...
# 8    9  [Assembly, Bash/Shell, C#, C++, Go, HTML/CSS, ...
# 9   10  [MATLAB, Python, R, SQL, Microsoft SQL Server,...
# 10  11  [Python, SQL, Microsoft SQL Server, MySQL, Mic...
# 11  12  [Assembly, Bash/Shell, C, C#, C++, HTML/CSS, J...
# 12  13  [Python, SQL, Microsoft SQL Server, MySQL, Mic...
# 13  14  [Python, SQL, Microsoft SQL Server, MySQL, ASP...
# 14  15  [Go, Java, JavaScript, MySQL, PostgreSQL, Goog...
# 15  16  [Bash/Shell, JavaScript, Python, SQL, DynamoDB...
# 16  17  [Bash/Shell, C#, C++, HTML/CSS, JavaScript, PH...
# 17  18  [C, Go, HTML/CSS, Java, JavaScript, Kotlin, Lu...
# 18  19  [MATLAB, Python, SQL, Microsoft SQL Server, Go...
#
#                                           skills-want  YearsCodePro  \
# 0                    [Dart, Java, SQL, MySQL, SQLite]           3.0
# 1   [HTML/CSS, JavaScript, TypeScript, AWS, Fireba...           4.0
# 2    [Python, MySQL, SQLite, Unity 3D, Unreal Engine]           4.0
# 3   [HTML/CSS, JavaScript, TypeScript, AWS, Fireba...           2.0
# 4   [Python, R, SQL, Microsoft SQL Server, MySQL, ...           9.0
# 5   [Python, Microsoft SQL Server, MongoDB, Neo4j,...           1.0
# 6   [Python, R, Scala, Microsoft SQL Server, Mongo...          12.0
# 7   [C#, Python, SQL, Cassandra, MariaDB, Microsof...           6.0
# 8   [C#, Go, HTML/CSS, Java, JavaScript, PowerShel...           0.0
# 9   [C++, Python, Scala, DynamoDB, MongoDB, MySQL,...           1.5
# 10  [Python, SQL, Microsoft SQL Server, MySQL, Pos...           2.0
# 11  [C++, Python, MySQL, Microsoft Azure, Keras, N...           5.0
# 12  [Python, Microsoft SQL Server, MySQL, Microsof...           5.0
# 13  [R, DynamoDB, MongoDB, SQLite, AWS, Microsoft ...           4.0
# 14  [Java, TypeScript, DynamoDB, Microsoft SQL Ser...           6.0
# 15  [Kotlin, Ruby, Rust, Redis, Google Cloud, Djan...          11.0
# 16  [Bash/Shell, C#, JavaScript, PowerShell, SQL, ...          10.0
# 17  [C#, HTML/CSS, JavaScript, Python, Rust, TypeS...           2.0
# 18                             [SQL, Microsoft Azure]           2.0
#
#     similarity_score_skills  similarity_score_interests
# 0                  0.116732                    0.000000
# 1                  0.000000                    0.184770
# 2                  0.043909                    0.164968
# 3                  0.280536                    0.168137
# 4                  0.526111                    0.767549
# 5                  0.480727                    0.617460
# 6                  0.682146                    0.609960
# 7                  0.572735                    0.888038
# 8                  0.407636                    0.467402
# 9                  1.000000                    0.190599
# 10                 0.908212                    1.000000
# 11                 0.409159                    0.563311
# 12                 0.715809                    0.830200
# 13                 0.618861                    0.265835
# 14                 0.177790                    0.440864
# 15                 0.638209                    0.266082
# 16                 0.625730                    0.876245
# 17                 0.312888                    0.143803
# 18                 0.606783                    0.476240

# %% [markdown]
# ## Score from Experience

# %%
# Define bin edges for each level of experience
bin_edges = [-1, 2, 5, 10, 50]

# Define the labels for each level of experience
labels = ['Junior', 'Associate', 'Senior', 'Architect']

# Convert the 'years' column to categorical levels of experience
df_people['Experience'] = pd.cut(pd.to_numeric(df_people['YearsCodePro']), bins=bin_edges, labels=labels)

df_people
# Out:
#     id                                             skills  \
# 0    1  [Java, JavaScript, Python, SQL, MySQL, SQLite,...
# 1    2  [C++, HTML/CSS, Java, JavaScript, PHP, Python,...
# 2    3  [C++, HTML/CSS, Java, PHP, Python, SQL, MariaD...
# 3    4  [HTML/CSS, JavaScript, Kotlin, TypeScript, AWS...
# 4    5  [C#, Java, JavaScript, PHP, PowerShell, Python...
# 5    6  [MATLAB, Python, R, SQL, Swift, Cassandra, Cou...
# 6    7  [Bash/Shell, PowerShell, Python, Scala, SQL, M...
# 7    8  [Bash/Shell, C#, C++, Java, PowerShell, Python...
# 8    9  [Assembly, Bash/Shell, C#, C++, Go, HTML/CSS, ...
# 9   10  [MATLAB, Python, R, SQL, Microsoft SQL Server,...
# 10  11  [Python, SQL, Microsoft SQL Server, MySQL, Mic...
# 11  12  [Assembly, Bash/Shell, C, C#, C++, HTML/CSS, J...
# 12  13  [Python, SQL, Microsoft SQL Server, MySQL, Mic...
# 13  14  [Python, SQL, Microsoft SQL Server, MySQL, ASP...
# 14  15  [Go, Java, JavaScript, MySQL, PostgreSQL, Goog...
# 15  16  [Bash/Shell, JavaScript, Python, SQL, DynamoDB...
# 16  17  [Bash/Shell, C#, C++, HTML/CSS, JavaScript, PH...
# 17  18  [C, Go, HTML/CSS, Java, JavaScript, Kotlin, Lu...
# 18  19  [MATLAB, Python, SQL, Microsoft SQL Server, Go...
#
#                                           skills-want  YearsCodePro  \
# 0                    [Dart, Java, SQL, MySQL, SQLite]           3.0
# 1   [HTML/CSS, JavaScript, TypeScript, AWS, Fireba...           4.0
# 2    [Python, MySQL, SQLite, Unity 3D, Unreal Engine]           4.0
# 3   [HTML/CSS, JavaScript, TypeScript, AWS, Fireba...           2.0
# 4   [Python, R, SQL, Microsoft SQL Server, MySQL, ...           9.0
# 5   [Python, Microsoft SQL Server, MongoDB, Neo4j,...           1.0
# 6   [Python, R, Scala, Microsoft SQL Server, Mongo...          12.0
# 7   [C#, Python, SQL, Cassandra, MariaDB, Microsof...           6.0
# 8   [C#, Go, HTML/CSS, Java, JavaScript, PowerShel...           0.0
# 9   [C++, Python, Scala, DynamoDB, MongoDB, MySQL,...           1.5
# 10  [Python, SQL, Microsoft SQL Server, MySQL, Pos...           2.0
# 11  [C++, Python, MySQL, Microsoft Azure, Keras, N...           5.0
# 12  [Python, Microsoft SQL Server, MySQL, Microsof...           5.0
# 13  [R, DynamoDB, MongoDB, SQLite, AWS, Microsoft ...           4.0
# 14  [Java, TypeScript, DynamoDB, Microsoft SQL Ser...           6.0
# 15  [Kotlin, Ruby, Rust, Redis, Google Cloud, Djan...          11.0
# 16  [Bash/Shell, C#, JavaScript, PowerShell, SQL, ...          10.0
# 17  [C#, HTML/CSS, JavaScript, Python, Rust, TypeS...           2.0
# 18                             [SQL, Microsoft Azure]           2.0
#
#     similarity_score_skills  similarity_score_interests Experience
# 0                  0.116732                    0.000000  Associate
# 1                  0.000000                    0.184770  Associate
# 2                  0.043909                    0.164968  Associate
# 3                  0.280536                    0.168137     Junior
# 4                  0.526111                    0.767549     Senior
# 5                  0.480727                    0.617460     Junior
# 6                  0.682146                    0.609960  Architect
# 7                  0.572735                    0.888038     Senior
# 8                  0.407636                    0.467402     Junior
# 9                  1.000000                    0.190599     Junior
# 10                 0.908212                    1.000000     Junior
# 11                 0.409159                    0.563311  Associate
# 12                 0.715809                    0.830200  Associate
# 13                 0.618861                    0.265835  Associate
# 14                 0.177790                    0.440864     Senior
# 15                 0.638209                    0.266082  Architect
# 16                 0.625730                    0.876245     Senior
# 17                 0.312888                    0.143803     Junior
# 18                 0.606783                    0.476240     Junior

# %%
from scipy.spatial.distance import euclidean

# Define a function to compute the similarity metric
def similarity(level1, level2):
    # Define the vectors representing the levels of experience
    levels = {'Junior': [0, 0, 0, 0],
              'Associate': [1, 0, 0, 0],
              'Senior': [1, 1, 0, 0],
              'Architect': [1, 1, 1, 0]}
    
    # Compute the Euclidean distance between the two vectors
    distance = euclidean(levels[level1], levels[level2])
    
    # Return the similarity metric
    return 1 / (1 + distance)

# %%
# Compute the similarity based on level
df_people['similarity_score_experience'] = df_people["Experience"].apply(lambda x: similarity(role_experience, x))
df_people
# Out:
#     id                                             skills  \
# 0    1  [Java, JavaScript, Python, SQL, MySQL, SQLite,...
# 1    2  [C++, HTML/CSS, Java, JavaScript, PHP, Python,...
# 2    3  [C++, HTML/CSS, Java, PHP, Python, SQL, MariaD...
# 3    4  [HTML/CSS, JavaScript, Kotlin, TypeScript, AWS...
# 4    5  [C#, Java, JavaScript, PHP, PowerShell, Python...
# 5    6  [MATLAB, Python, R, SQL, Swift, Cassandra, Cou...
# 6    7  [Bash/Shell, PowerShell, Python, Scala, SQL, M...
# 7    8  [Bash/Shell, C#, C++, Java, PowerShell, Python...
# 8    9  [Assembly, Bash/Shell, C#, C++, Go, HTML/CSS, ...
# 9   10  [MATLAB, Python, R, SQL, Microsoft SQL Server,...
# 10  11  [Python, SQL, Microsoft SQL Server, MySQL, Mic...
# 11  12  [Assembly, Bash/Shell, C, C#, C++, HTML/CSS, J...
# 12  13  [Python, SQL, Microsoft SQL Server, MySQL, Mic...
# 13  14  [Python, SQL, Microsoft SQL Server, MySQL, ASP...
# 14  15  [Go, Java, JavaScript, MySQL, PostgreSQL, Goog...
# 15  16  [Bash/Shell, JavaScript, Python, SQL, DynamoDB...
# 16  17  [Bash/Shell, C#, C++, HTML/CSS, JavaScript, PH...
# 17  18  [C, Go, HTML/CSS, Java, JavaScript, Kotlin, Lu...
# 18  19  [MATLAB, Python, SQL, Microsoft SQL Server, Go...
#
#                                           skills-want  YearsCodePro  \
# 0                    [Dart, Java, SQL, MySQL, SQLite]           3.0
# 1   [HTML/CSS, JavaScript, TypeScript, AWS, Fireba...           4.0
# 2    [Python, MySQL, SQLite, Unity 3D, Unreal Engine]           4.0
# 3   [HTML/CSS, JavaScript, TypeScript, AWS, Fireba...           2.0
# 4   [Python, R, SQL, Microsoft SQL Server, MySQL, ...           9.0
# 5   [Python, Microsoft SQL Server, MongoDB, Neo4j,...           1.0
# 6   [Python, R, Scala, Microsoft SQL Server, Mongo...          12.0
# 7   [C#, Python, SQL, Cassandra, MariaDB, Microsof...           6.0
# 8   [C#, Go, HTML/CSS, Java, JavaScript, PowerShel...           0.0
# 9   [C++, Python, Scala, DynamoDB, MongoDB, MySQL,...           1.5
# 10  [Python, SQL, Microsoft SQL Server, MySQL, Pos...           2.0
# 11  [C++, Python, MySQL, Microsoft Azure, Keras, N...           5.0
# 12  [Python, Microsoft SQL Server, MySQL, Microsof...           5.0
# 13  [R, DynamoDB, MongoDB, SQLite, AWS, Microsoft ...           4.0
# 14  [Java, TypeScript, DynamoDB, Microsoft SQL Ser...           6.0
# 15  [Kotlin, Ruby, Rust, Redis, Google Cloud, Djan...          11.0
# 16  [Bash/Shell, C#, JavaScript, PowerShell, SQL, ...          10.0
# 17  [C#, HTML/CSS, JavaScript, Python, Rust, TypeS...           2.0
# 18                             [SQL, Microsoft Azure]           2.0
#
#     similarity_score_skills  similarity_score_interests Experience  \
# 0                  0.116732                    0.000000  Associate
# 1                  0.000000                    0.184770  Associate
# 2                  0.043909                    0.164968  Associate
# 3                  0.280536                    0.168137     Junior
# 4                  0.526111                    0.767549     Senior
# 5                  0.480727                    0.617460     Junior
# 6                  0.682146                    0.609960  Architect
# 7                  0.572735                    0.888038     Senior
# 8                  0.407636                    0.467402     Junior
# 9                  1.000000                    0.190599     Junior
# 10                 0.908212                    1.000000     Junior
# 11                 0.409159                    0.563311  Associate
# 12                 0.715809                    0.830200  Associate
# 13                 0.618861                    0.265835  Associate
# 14                 0.177790                    0.440864     Senior
# 15                 0.638209                    0.266082  Architect
# 16                 0.625730                    0.876245     Senior
# 17                 0.312888                    0.143803     Junior
# 18                 0.606783                    0.476240     Junior
#
#     similarity_score_experience
# 0                      1.000000
# 1                      1.000000
# 2                      1.000000
# 3                      0.500000
# 4                      0.500000
# 5                      0.500000
# 6                      0.414214
# 7                      0.500000
# 8                      0.500000
# 9                      0.500000
# 10                     0.500000
# 11                     1.000000
# 12                     1.000000
# 13                     1.000000
# 14                     0.500000
# 15                     0.414214
# 16                     0.500000
# 17                     0.500000
# 18                     0.500000

# %% [markdown]
# # Add Results from all 3 Models

# %% [markdown]
# ## Model 1 - Compute Final Score

# %%
# Set weights
weight_skills = 0.8
weight_interests = 0
weight_experience = 0.2

# Calculate final score
df_people['score-model1'] = df_people['similarity_score_skills'] * weight_skills + df_people['similarity_score_interests'] * weight_interests + df_people['similarity_score_experience'] * weight_experience

df_people
# Out:
#     id                                             skills  \
# 0    1  [Java, JavaScript, Python, SQL, MySQL, SQLite,...
# 1    2  [C++, HTML/CSS, Java, JavaScript, PHP, Python,...
# 2    3  [C++, HTML/CSS, Java, PHP, Python, SQL, MariaD...
# 3    4  [HTML/CSS, JavaScript, Kotlin, TypeScript, AWS...
# 4    5  [C#, Java, JavaScript, PHP, PowerShell, Python...
# 5    6  [MATLAB, Python, R, SQL, Swift, Cassandra, Cou...
# 6    7  [Bash/Shell, PowerShell, Python, Scala, SQL, M...
# 7    8  [Bash/Shell, C#, C++, Java, PowerShell, Python...
# 8    9  [Assembly, Bash/Shell, C#, C++, Go, HTML/CSS, ...
# 9   10  [MATLAB, Python, R, SQL, Microsoft SQL Server,...
# 10  11  [Python, SQL, Microsoft SQL Server, MySQL, Mic...
# 11  12  [Assembly, Bash/Shell, C, C#, C++, HTML/CSS, J...
# 12  13  [Python, SQL, Microsoft SQL Server, MySQL, Mic...
# 13  14  [Python, SQL, Microsoft SQL Server, MySQL, ASP...
# 14  15  [Go, Java, JavaScript, MySQL, PostgreSQL, Goog...
# 15  16  [Bash/Shell, JavaScript, Python, SQL, DynamoDB...
# 16  17  [Bash/Shell, C#, C++, HTML/CSS, JavaScript, PH...
# 17  18  [C, Go, HTML/CSS, Java, JavaScript, Kotlin, Lu...
# 18  19  [MATLAB, Python, SQL, Microsoft SQL Server, Go...
#
#                                           skills-want  YearsCodePro  \
# 0                    [Dart, Java, SQL, MySQL, SQLite]           3.0
# 1   [HTML/CSS, JavaScript, TypeScript, AWS, Fireba...           4.0
# 2    [Python, MySQL, SQLite, Unity 3D, Unreal Engine]           4.0
# 3   [HTML/CSS, JavaScript, TypeScript, AWS, Fireba...           2.0
# 4   [Python, R, SQL, Microsoft SQL Server, MySQL, ...           9.0
# 5   [Python, Microsoft SQL Server, MongoDB, Neo4j,...           1.0
# 6   [Python, R, Scala, Microsoft SQL Server, Mongo...          12.0
# 7   [C#, Python, SQL, Cassandra, MariaDB, Microsof...           6.0
# 8   [C#, Go, HTML/CSS, Java, JavaScript, PowerShel...           0.0
# 9   [C++, Python, Scala, DynamoDB, MongoDB, MySQL,...           1.5
# 10  [Python, SQL, Microsoft SQL Server, MySQL, Pos...           2.0
# 11  [C++, Python, MySQL, Microsoft Azure, Keras, N...           5.0
# 12  [Python, Microsoft SQL Server, MySQL, Microsof...           5.0
# 13  [R, DynamoDB, MongoDB, SQLite, AWS, Microsoft ...           4.0
# 14  [Java, TypeScript, DynamoDB, Microsoft SQL Ser...           6.0
# 15  [Kotlin, Ruby, Rust, Redis, Google Cloud, Djan...          11.0
# 16  [Bash/Shell, C#, JavaScript, PowerShell, SQL, ...          10.0
# 17  [C#, HTML/CSS, JavaScript, Python, Rust, TypeS...           2.0
# 18                             [SQL, Microsoft Azure]           2.0
#
#     similarity_score_skills  similarity_score_interests Experience  \
# 0                  0.116732                    0.000000  Associate
# 1                  0.000000                    0.184770  Associate
# 2                  0.043909                    0.164968  Associate
# 3                  0.280536                    0.168137     Junior
# 4                  0.526111                    0.767549     Senior
# 5                  0.480727                    0.617460     Junior
# 6                  0.682146                    0.609960  Architect
# 7                  0.572735                    0.888038     Senior
# 8                  0.407636                    0.467402     Junior
# 9                  1.000000                    0.190599     Junior
# 10                 0.908212                    1.000000     Junior
# 11                 0.409159                    0.563311  Associate
# 12                 0.715809                    0.830200  Associate
# 13                 0.618861                    0.265835  Associate
# 14                 0.177790                    0.440864     Senior
# 15                 0.638209                    0.266082  Architect
# 16                 0.625730                    0.876245     Senior
# 17                 0.312888                    0.143803     Junior
# 18                 0.606783                    0.476240     Junior
#
#     similarity_score_experience  score-model1
# 0                      1.000000      0.293385
# 1                      1.000000      0.200000
# 2                      1.000000      0.235127
# 3                      0.500000      0.324429
# 4                      0.500000      0.520889
# 5                      0.500000      0.484581
# 6                      0.414214      0.628559
# 7                      0.500000      0.558188
# 8                      0.500000      0.426109
# 9                      0.500000      0.900000
# 10                     0.500000      0.826570
# 11                     1.000000      0.527327
# 12                     1.000000      0.772648
# 13                     1.000000      0.695089
# 14                     0.500000      0.242232
# 15                     0.414214      0.593410
# 16                     0.500000      0.600584
# 17                     0.500000      0.350311
# 18                     0.500000      0.585426

# %% [markdown]
# ## Model 2 - Compute Final score

# %%
# Set weights
weight_skills = 0.4
weight_interests = 0.4
weight_experience = 0.2

# Calculate final score
df_people['score-model2'] = df_people['similarity_score_skills'] * weight_skills + df_people['similarity_score_interests'] * weight_interests + df_people['similarity_score_experience'] * weight_experience

df_people
# Out:
#     id                                             skills  \
# 0    1  [Java, JavaScript, Python, SQL, MySQL, SQLite,...
# 1    2  [C++, HTML/CSS, Java, JavaScript, PHP, Python,...
# 2    3  [C++, HTML/CSS, Java, PHP, Python, SQL, MariaD...
# 3    4  [HTML/CSS, JavaScript, Kotlin, TypeScript, AWS...
# 4    5  [C#, Java, JavaScript, PHP, PowerShell, Python...
# 5    6  [MATLAB, Python, R, SQL, Swift, Cassandra, Cou...
# 6    7  [Bash/Shell, PowerShell, Python, Scala, SQL, M...
# 7    8  [Bash/Shell, C#, C++, Java, PowerShell, Python...
# 8    9  [Assembly, Bash/Shell, C#, C++, Go, HTML/CSS, ...
# 9   10  [MATLAB, Python, R, SQL, Microsoft SQL Server,...
# 10  11  [Python, SQL, Microsoft SQL Server, MySQL, Mic...
# 11  12  [Assembly, Bash/Shell, C, C#, C++, HTML/CSS, J...
# 12  13  [Python, SQL, Microsoft SQL Server, MySQL, Mic...
# 13  14  [Python, SQL, Microsoft SQL Server, MySQL, ASP...
# 14  15  [Go, Java, JavaScript, MySQL, PostgreSQL, Goog...
# 15  16  [Bash/Shell, JavaScript, Python, SQL, DynamoDB...
# 16  17  [Bash/Shell, C#, C++, HTML/CSS, JavaScript, PH...
# 17  18  [C, Go, HTML/CSS, Java, JavaScript, Kotlin, Lu...
# 18  19  [MATLAB, Python, SQL, Microsoft SQL Server, Go...
#
#                                           skills-want  YearsCodePro  \
# 0                    [Dart, Java, SQL, MySQL, SQLite]           3.0
# 1   [HTML/CSS, JavaScript, TypeScript, AWS, Fireba...           4.0
# 2    [Python, MySQL, SQLite, Unity 3D, Unreal Engine]           4.0
# 3   [HTML/CSS, JavaScript, TypeScript, AWS, Fireba...           2.0
# 4   [Python, R, SQL, Microsoft SQL Server, MySQL, ...           9.0
# 5   [Python, Microsoft SQL Server, MongoDB, Neo4j,...           1.0
# 6   [Python, R, Scala, Microsoft SQL Server, Mongo...          12.0
# 7   [C#, Python, SQL, Cassandra, MariaDB, Microsof...           6.0
# 8   [C#, Go, HTML/CSS, Java, JavaScript, PowerShel...           0.0
# 9   [C++, Python, Scala, DynamoDB, MongoDB, MySQL,...           1.5
# 10  [Python, SQL, Microsoft SQL Server, MySQL, Pos...           2.0
# 11  [C++, Python, MySQL, Microsoft Azure, Keras, N...           5.0
# 12  [Python, Microsoft SQL Server, MySQL, Microsof...           5.0
# 13  [R, DynamoDB, MongoDB, SQLite, AWS, Microsoft ...           4.0
# 14  [Java, TypeScript, DynamoDB, Microsoft SQL Ser...           6.0
# 15  [Kotlin, Ruby, Rust, Redis, Google Cloud, Djan...          11.0
# 16  [Bash/Shell, C#, JavaScript, PowerShell, SQL, ...          10.0
# 17  [C#, HTML/CSS, JavaScript, Python, Rust, TypeS...           2.0
# 18                             [SQL, Microsoft Azure]           2.0
#
#     similarity_score_skills  similarity_score_interests Experience  \
# 0                  0.116732                    0.000000  Associate
# 1                  0.000000                    0.184770  Associate
# 2                  0.043909                    0.164968  Associate
# 3                  0.280536                    0.168137     Junior
# 4                  0.526111                    0.767549     Senior
# 5                  0.480727                    0.617460     Junior
# 6                  0.682146                    0.609960  Architect
# 7                  0.572735                    0.888038     Senior
# 8                  0.407636                    0.467402     Junior
# 9                  1.000000                    0.190599     Junior
# 10                 0.908212                    1.000000     Junior
# 11                 0.409159                    0.563311  Associate
# 12                 0.715809                    0.830200  Associate
# 13                 0.618861                    0.265835  Associate
# 14                 0.177790                    0.440864     Senior
# 15                 0.638209                    0.266082  Architect
# 16                 0.625730                    0.876245     Senior
# 17                 0.312888                    0.143803     Junior
# 18                 0.606783                    0.476240     Junior
#
#     similarity_score_experience  score-model1  score-model2
# 0                      1.000000      0.293385      0.246693
# 1                      1.000000      0.200000      0.273908
# 2                      1.000000      0.235127      0.283551
# 3                      0.500000      0.324429      0.279469
# 4                      0.500000      0.520889      0.617464
# 5                      0.500000      0.484581      0.539275
# 6                      0.414214      0.628559      0.599685
# 7                      0.500000      0.558188      0.684309
# 8                      0.500000      0.426109      0.450016
# 9                      0.500000      0.900000      0.576240
# 10                     0.500000      0.826570      0.863285
# 11                     1.000000      0.527327      0.588988
# 12                     1.000000      0.772648      0.818404
# 13                     1.000000      0.695089      0.553878
# 14                     0.500000      0.242232      0.347461
# 15                     0.414214      0.593410      0.444559
# 16                     0.500000      0.600584      0.700790
# 17                     0.500000      0.350311      0.282677
# 18                     0.500000      0.585426      0.533209

# %% [markdown]
# ## Model 3 - Compute Final Score

# %%
# Set weights
weight_skills = 0
weight_interests = 0.8
weight_experience = 0.2

# Calculate final score
df_people['score-model3'] = df_people['similarity_score_skills'] * weight_skills + df_people['similarity_score_interests'] * weight_interests + df_people['similarity_score_experience'] * weight_experience

df_people
# Out:
#     id                                             skills  \
# 0    1  [Java, JavaScript, Python, SQL, MySQL, SQLite,...
# 1    2  [C++, HTML/CSS, Java, JavaScript, PHP, Python,...
# 2    3  [C++, HTML/CSS, Java, PHP, Python, SQL, MariaD...
# 3    4  [HTML/CSS, JavaScript, Kotlin, TypeScript, AWS...
# 4    5  [C#, Java, JavaScript, PHP, PowerShell, Python...
# 5    6  [MATLAB, Python, R, SQL, Swift, Cassandra, Cou...
# 6    7  [Bash/Shell, PowerShell, Python, Scala, SQL, M...
# 7    8  [Bash/Shell, C#, C++, Java, PowerShell, Python...
# 8    9  [Assembly, Bash/Shell, C#, C++, Go, HTML/CSS, ...
# 9   10  [MATLAB, Python, R, SQL, Microsoft SQL Server,...
# 10  11  [Python, SQL, Microsoft SQL Server, MySQL, Mic...
# 11  12  [Assembly, Bash/Shell, C, C#, C++, HTML/CSS, J...
# 12  13  [Python, SQL, Microsoft SQL Server, MySQL, Mic...
# 13  14  [Python, SQL, Microsoft SQL Server, MySQL, ASP...
# 14  15  [Go, Java, JavaScript, MySQL, PostgreSQL, Goog...
# 15  16  [Bash/Shell, JavaScript, Python, SQL, DynamoDB...
# 16  17  [Bash/Shell, C#, C++, HTML/CSS, JavaScript, PH...
# 17  18  [C, Go, HTML/CSS, Java, JavaScript, Kotlin, Lu...
# 18  19  [MATLAB, Python, SQL, Microsoft SQL Server, Go...
#
#                                           skills-want  YearsCodePro  \
# 0                    [Dart, Java, SQL, MySQL, SQLite]           3.0
# 1   [HTML/CSS, JavaScript, TypeScript, AWS, Fireba...           4.0
# 2    [Python, MySQL, SQLite, Unity 3D, Unreal Engine]           4.0
# 3   [HTML/CSS, JavaScript, TypeScript, AWS, Fireba...           2.0
# 4   [Python, R, SQL, Microsoft SQL Server, MySQL, ...           9.0
# 5   [Python, Microsoft SQL Server, MongoDB, Neo4j,...           1.0
# 6   [Python, R, Scala, Microsoft SQL Server, Mongo...          12.0
# 7   [C#, Python, SQL, Cassandra, MariaDB, Microsof...           6.0
# 8   [C#, Go, HTML/CSS, Java, JavaScript, PowerShel...           0.0
# 9   [C++, Python, Scala, DynamoDB, MongoDB, MySQL,...           1.5
# 10  [Python, SQL, Microsoft SQL Server, MySQL, Pos...           2.0
# 11  [C++, Python, MySQL, Microsoft Azure, Keras, N...           5.0
# 12  [Python, Microsoft SQL Server, MySQL, Microsof...           5.0
# 13  [R, DynamoDB, MongoDB, SQLite, AWS, Microsoft ...           4.0
# 14  [Java, TypeScript, DynamoDB, Microsoft SQL Ser...           6.0
# 15  [Kotlin, Ruby, Rust, Redis, Google Cloud, Djan...          11.0
# 16  [Bash/Shell, C#, JavaScript, PowerShell, SQL, ...          10.0
# 17  [C#, HTML/CSS, JavaScript, Python, Rust, TypeS...           2.0
# 18                             [SQL, Microsoft Azure]           2.0
#
#     similarity_score_skills  similarity_score_interests Experience  \
# 0                  0.116732                    0.000000  Associate
# 1                  0.000000                    0.184770  Associate
# 2                  0.043909                    0.164968  Associate
# 3                  0.280536                    0.168137     Junior
# 4                  0.526111                    0.767549     Senior
# 5                  0.480727                    0.617460     Junior
# 6                  0.682146                    0.609960  Architect
# 7                  0.572735                    0.888038     Senior
# 8                  0.407636                    0.467402     Junior
# 9                  1.000000                    0.190599     Junior
# 10                 0.908212                    1.000000     Junior
# 11                 0.409159                    0.563311  Associate
# 12                 0.715809                    0.830200  Associate
# 13                 0.618861                    0.265835  Associate
# 14                 0.177790                    0.440864     Senior
# 15                 0.638209                    0.266082  Architect
# 16                 0.625730                    0.876245     Senior
# 17                 0.312888                    0.143803     Junior
# 18                 0.606783                    0.476240     Junior
#
#     similarity_score_experience  score-model1  score-model2  score-model3
# 0                      1.000000      0.293385      0.246693      0.200000
# 1                      1.000000      0.200000      0.273908      0.347816
# 2                      1.000000      0.235127      0.283551      0.331975
# 3                      0.500000      0.324429      0.279469      0.234510
# 4                      0.500000      0.520889      0.617464      0.714039
# 5                      0.500000      0.484581      0.539275      0.593968
# 6                      0.414214      0.628559      0.599685      0.570811
# 7                      0.500000      0.558188      0.684309      0.810431
# 8                      0.500000      0.426109      0.450016      0.473922
# 9                      0.500000      0.900000      0.576240      0.252480
# 10                     0.500000      0.826570      0.863285      0.900000
# 11                     1.000000      0.527327      0.588988      0.650649
# 12                     1.000000      0.772648      0.818404      0.864160
# 13                     1.000000      0.695089      0.553878      0.412668
# 14                     0.500000      0.242232      0.347461      0.452691
# 15                     0.414214      0.593410      0.444559      0.295708
# 16                     0.500000      0.600584      0.700790      0.800996
# 17                     0.500000      0.350311      0.282677      0.215043
# 18                     0.500000      0.585426      0.533209      0.480992

# %% [markdown]
# # Add Column for Ordering the List

# %%
# Rank similarities
df_people['rank-model1'] = df_people['score-model1'].rank(ascending=False)
df_people['rank-model2'] = df_people['score-model2'].rank(ascending=False)
df_people['rank-model3'] = df_people['score-model3'].rank(ascending=False)

# Select only required columns
df_people = df_people[['id','skills','skills-want', 'Experience', 'rank-model1', 'rank-model2', 'rank-model3']]

df_people
# Out:
#     id                                             skills  \
# 0    1  [Java, JavaScript, Python, SQL, MySQL, SQLite,...
# 1    2  [C++, HTML/CSS, Java, JavaScript, PHP, Python,...
# 2    3  [C++, HTML/CSS, Java, PHP, Python, SQL, MariaD...
# 3    4  [HTML/CSS, JavaScript, Kotlin, TypeScript, AWS...
# 4    5  [C#, Java, JavaScript, PHP, PowerShell, Python...
# 5    6  [MATLAB, Python, R, SQL, Swift, Cassandra, Cou...
# 6    7  [Bash/Shell, PowerShell, Python, Scala, SQL, M...
# 7    8  [Bash/Shell, C#, C++, Java, PowerShell, Python...
# 8    9  [Assembly, Bash/Shell, C#, C++, Go, HTML/CSS, ...
# 9   10  [MATLAB, Python, R, SQL, Microsoft SQL Server,...
# 10  11  [Python, SQL, Microsoft SQL Server, MySQL, Mic...
# 11  12  [Assembly, Bash/Shell, C, C#, C++, HTML/CSS, J...
# 12  13  [Python, SQL, Microsoft SQL Server, MySQL, Mic...
# 13  14  [Python, SQL, Microsoft SQL Server, MySQL, ASP...
# 14  15  [Go, Java, JavaScript, MySQL, PostgreSQL, Goog...
# 15  16  [Bash/Shell, JavaScript, Python, SQL, DynamoDB...
# 16  17  [Bash/Shell, C#, C++, HTML/CSS, JavaScript, PH...
# 17  18  [C, Go, HTML/CSS, Java, JavaScript, Kotlin, Lu...
# 18  19  [MATLAB, Python, SQL, Microsoft SQL Server, Go...
#
#                                           skills-want Experience  rank-model1  \
# 0                    [Dart, Java, SQL, MySQL, SQLite]  Associate         16.0
# 1   [HTML/CSS, JavaScript, TypeScript, AWS, Fireba...  Associate         19.0
# 2    [Python, MySQL, SQLite, Unity 3D, Unreal Engine]  Associate         18.0
# 3   [HTML/CSS, JavaScript, TypeScript, AWS, Fireba...     Junior         15.0
# 4   [Python, R, SQL, Microsoft SQL Server, MySQL, ...     Senior         11.0
# 5   [Python, Microsoft SQL Server, MongoDB, Neo4j,...     Junior         12.0
# 6   [Python, R, Scala, Microsoft SQL Server, Mongo...  Architect          5.0
# 7   [C#, Python, SQL, Cassandra, MariaDB, Microsof...     Senior          9.0
# 8   [C#, Go, HTML/CSS, Java, JavaScript, PowerShel...     Junior         13.0
# 9   [C++, Python, Scala, DynamoDB, MongoDB, MySQL,...     Junior          1.0
# 10  [Python, SQL, Microsoft SQL Server, MySQL, Pos...     Junior          2.0
# 11  [C++, Python, MySQL, Microsoft Azure, Keras, N...  Associate         10.0
# 12  [Python, Microsoft SQL Server, MySQL, Microsof...  Associate          3.0
# 13  [R, DynamoDB, MongoDB, SQLite, AWS, Microsoft ...  Associate          4.0
# 14  [Java, TypeScript, DynamoDB, Microsoft SQL Ser...     Senior         17.0
# 15  [Kotlin, Ruby, Rust, Redis, Google Cloud, Djan...  Architect          7.0
# 16  [Bash/Shell, C#, JavaScript, PowerShell, SQL, ...     Senior          6.0
# 17  [C#, HTML/CSS, JavaScript, Python, Rust, TypeS...     Junior         14.0
# 18                             [SQL, Microsoft Azure]     Junior          8.0
#
#     rank-model2  rank-model3
# 0          19.0         19.0
# 1          18.0         13.0
# 2          15.0         14.0
# 3          17.0         17.0
# 4           5.0          5.0
# 5          10.0          7.0
# 6           6.0          8.0
# 7           4.0          3.0
# 8          12.0         10.0
# 9           8.0         16.0
# 10          1.0          1.0
# 11          7.0          6.0
# 12          2.0          2.0
# 13          9.0         12.0
# 14         14.0         11.0
# 15         13.0         15.0
# 16          3.0          4.0
# 17         16.0         18.0
# 18         11.0          9.0

# %%
df_people = df_people[(df_people['rank-model1']<4) | (df_people['rank-model2']<4) | (df_people['rank-model3']<4)]
df_people
# Out:
#     id                                             skills  \
# 7    8  [Bash/Shell, C#, C++, Java, PowerShell, Python...
# 9   10  [MATLAB, Python, R, SQL, Microsoft SQL Server,...
# 10  11  [Python, SQL, Microsoft SQL Server, MySQL, Mic...
# 12  13  [Python, SQL, Microsoft SQL Server, MySQL, Mic...
# 16  17  [Bash/Shell, C#, C++, HTML/CSS, JavaScript, PH...
#
#                                           skills-want Experience  rank-model1  \
# 7   [C#, Python, SQL, Cassandra, MariaDB, Microsof...     Senior          9.0
# 9   [C++, Python, Scala, DynamoDB, MongoDB, MySQL,...     Junior          1.0
# 10  [Python, SQL, Microsoft SQL Server, MySQL, Pos...     Junior          2.0
# 12  [Python, Microsoft SQL Server, MySQL, Microsof...  Associate          3.0
# 16  [Bash/Shell, C#, JavaScript, PowerShell, SQL, ...     Senior          6.0
#
#     rank-model2  rank-model3
# 7           4.0          3.0
# 9           8.0         16.0
# 10          1.0          1.0
# 12          2.0          2.0
# 16          3.0          4.0

# %% [markdown]
# # Export Results

# %%
df_people.to_csv(f"../6-results/rating_role_{role_id}.csv")
df_people
# Out:
#     id                                             skills  \
# 7    8  [Bash/Shell, C#, C++, Java, PowerShell, Python...
# 9   10  [MATLAB, Python, R, SQL, Microsoft SQL Server,...
# 10  11  [Python, SQL, Microsoft SQL Server, MySQL, Mic...
# 12  13  [Python, SQL, Microsoft SQL Server, MySQL, Mic...
# 16  17  [Bash/Shell, C#, C++, HTML/CSS, JavaScript, PH...
#
#                                           skills-want Experience  rank-model1  \
# 7   [C#, Python, SQL, Cassandra, MariaDB, Microsof...     Senior          9.0
# 9   [C++, Python, Scala, DynamoDB, MongoDB, MySQL,...     Junior          1.0
# 10  [Python, SQL, Microsoft SQL Server, MySQL, Pos...     Junior          2.0
# 12  [Python, Microsoft SQL Server, MySQL, Microsof...  Associate          3.0
# 16  [Bash/Shell, C#, JavaScript, PowerShell, SQL, ...     Senior          6.0
#
#     rank-model2  rank-model3
# 7           4.0          3.0
# 9           8.0         16.0
# 10          1.0          1.0
# 12          2.0          2.0
# 16          3.0          4.0
