# %% [markdown]
# # Models for ranking
#
# One single word embedding model is used for modelling the similarities between skills, which is used also for interests.
# A score is calculated from each Word Mover's Distance computed and a final score is calculated as a weighted combination of all scores.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
from gensim.models import Word2Vec
import numpy as np

# %% [markdown]
# # Load Employees Dataset

# %%
# Read the StackOverflow dataset
df_people = pd.read_csv(filepath_or_buffer="../2-data/employees.csv", sep=",", encoding="latin1")

# Tokenize the skills
df_people['skills'] = df_people['skills'].apply(lambda x: x.split(';'))

df_people = df_people[['id', 'skills', 'skills-want', 'YearsCodePro']]
df_people
# Out:
#           id                                             skills  \
# 0          2                           [JavaScript, TypeScript]
# 1          3  [C#, C++, HTML/CSS, JavaScript, Python, Micros...
# 2          4  [C#, JavaScript, SQL, TypeScript, Microsoft SQ...
# 3          5  [C#, HTML/CSS, JavaScript, SQL, Swift, TypeScr...
# 4          6                       [C++, Lua, , , , , Homebrew]
# ...      ...                                                ...
# 68545  73264  [Bash/Shell, Dart, JavaScript, PHP, Python, SQ...
# 68546  73265  [Bash/Shell, HTML/CSS, JavaScript, Python, SQL...
# 68547  73266  [HTML/CSS, JavaScript, PHP, Python, SQL, Maria...
# 68548  73267  [C#, Delphi, VBA, Microsoft SQL Server, MongoD...
# 68549  73268  [C#, JavaScript, Lua, PowerShell, SQL, TypeScr...
#
#                                              skills-want  YearsCodePro
# 0                                        Rust;TypeScript             0
# 1      C#;C++;HTML/CSS;JavaScript;TypeScript;Microsof...             5
# 2      C#;SQL;TypeScript;Microsoft SQL Server;;ASP.NE...            17
# 3      C#;Elixir;F#;Go;JavaScript;Rust;TypeScript;Clo...             3
# 4                                       Lua;;;;;Homebrew             0
# ...                                                  ...           ...
# 68545  Bash/Shell;Go;JavaScript;Python;SQL;TypeScript...             5
# 68546  HTML/CSS;JavaScript;Python;Elasticsearch;Neo4j...             5
# 68547  C#;HTML/CSS;JavaScript;PHP;Python;SQL;MariaDB;...            33
# 68548                                             Delphi            31
# 68549  PowerShell;Rust;TypeScript;Neo4j;Redis;AWS;Goo...             5
#
# [68550 rows x 4 columns]

# %% [markdown]
# # Load Word Embedding Model

# %%
model = Word2Vec.load("../3-word_embedding/model-w2vcombined")

# %% [markdown]
# # Prepare StackOverflow Dataset as available people

# %%
# Get only a sample
#df_people = df_people.sample(5)

# %% [markdown]
# # Find People to a Role

# %% [markdown]
# ## Get Role's Requirements

# %%
# Get the role requirements
role_skills = ['Python', 'Microsoft SQL Server', 'Microsoft Azure']
#role_experience = 5 # years
role_experience = 'Associate'

# %% [markdown]
# ## WMD to get most similar people

# %%
# Normalize scores
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# %% [markdown]
# ### Score from Skills

# %%
# Calculate the distance between the person's skills and the role skills
similarity_scores = []
for skills in df_people['skills']:
    similarity_scores.append(model.wv.wmdistance(role_skills, skills))
    #print('---> ')
    #print(role_skills)
    #print(skills)
    #print(model.wv.wmdistance(role_skills, skills))

# Add the dissimilarity score to each role
df_people['similarity_score_skills'] = similarity_scores


# Get the highest distance before inf
df_temp = df_people.loc[(df_people['similarity_score_skills'] < np.inf)]
max_score = df_temp['similarity_score_skills'].max()
print(max_score)

# Remove rows where the score is inf - meaning there is no similarity
df_people['similarity_score_skills'] = df_people['similarity_score_skills'].replace(np.inf, max_score)

#df = df.loc[(df['similarity_score_skills'] < np.inf)]

# Normalize scores and convert distance to similarity - 0 = more dissimilar, 1 = more similar
df_people['similarity_score_skills'] = 1 - scaler.fit_transform(df_people[['similarity_score_skills']])

# Sort the roles by similarity score
df_people = df_people.sort_values(by=['similarity_score_skills'], ascending=False)

df_people.head(5)
# Out:
# 1.1228630019251025
#           id                                             skills  \
# 38615  40867    [Python, Microsoft SQL Server, Microsoft Azure]
# 32645  34478  [Python, Microsoft SQL Server, SQLite, Microso...
# 34605  36569            [Python, MariaDB, Microsoft SQL Server]
# 40454  42833  [Python, SQL, Microsoft SQL Server, Microsoft ...
# 14316  14973                     [Python, Microsoft SQL Server]
#
#                                              skills-want  YearsCodePro  \
# 38615                        Python;Microsoft SQL Server             0
# 32645  Python;Rust;Microsoft SQL Server;SQLite;Micros...             2
# 34605                                           Java;SQL             0
# 40454    Python;SQL;Microsoft SQL Server;Microsoft Azure             5
# 14316  HTML/CSS;JavaScript;PowerShell;Python;SQL;Micr...            13
#
#        similarity_score_skills
# 38615                 1.000000
# 32645                 0.812893
# 34605                 0.795268
# 40454                 0.777396
# 14316                 0.736635

# %% [markdown]
# ### Score from Interests

# %%
# Tokenize the skills
df_people['skills-want'] = df_people['skills-want'].apply(lambda x: x.split(';'))

# Calculate the similarity between the person's skills and the role skills
similarity_scores = []
for skills in df_people['skills-want']:
    similarity_scores.append(model.wv.wmdistance(role_skills, skills))

# Add the similarity scores to each role
df_people['similarity_score_interests'] = similarity_scores

# Get the highest distance before inf
df_temp = df_people.loc[(df_people['similarity_score_interests'] < np.inf)]
max_score = df_temp['similarity_score_interests'].max()
print(max_score)

# Remove rows where the score is inf - meaning there is no similarity
df_people['similarity_score_interests'] = df_people['similarity_score_interests'].replace(np.inf, max_score)

#df = df.loc[(df['similarity_score_interests'] < np.inf)]

# Normalize scores and convert distance to similarity - 0 = more dissimilar, 1 = more similar
df_people['similarity_score_interests'] =  1 - scaler.fit_transform(df_people[['similarity_score_interests']])

# Sort the roles by similarity score
df_people = df_people.sort_values(by=['similarity_score_interests'], ascending=False)

df_people.head(5)
# Out:
# 1.1228630019251025
#           id                                             skills  \
# 20218  21170  [SQL, VBA, Microsoft SQL Server, Microsoft Azure]
# 38383  40624  [Java, SQL, MySQL, PostgreSQL, SQLite, AWS, , ...
# 67705  72374  [Python, Microsoft SQL Server, Google Cloud, ,...
# 17791  18627  [SQL, Microsoft SQL Server, PostgreSQL, , , , ...
# 40454  42833  [Python, SQL, Microsoft SQL Server, Microsoft ...
#
#                                              skills-want  YearsCodePro  \
# 20218    [Python, Microsoft SQL Server, Microsoft Azure]             0
# 38383    [Python, Microsoft SQL Server, Microsoft Azure]             0
# 67705       [Python, Microsoft SQL Server, Google Cloud]             0
# 17791         [Python, Microsoft SQL Server, PostgreSQL]            15
# 40454  [Python, SQL, Microsoft SQL Server, Microsoft ...             5
#
#        similarity_score_skills  similarity_score_interests
# 20218                 0.599823                    1.000000
# 38383                 0.182016                    1.000000
# 67705                 0.539348                    0.795118
# 17791                 0.231775                    0.781387
# 40454                 0.777396                    0.777396

# %% [markdown]
# ### Score from Experience

# %%
# define the bin edges for each level of experience
bin_edges = [-1, 4, 8, 12, 100]

# define the labels for each level of experience
labels = ['Junior', 'Associate', 'Senior', 'Architect']

# convert the 'years' column to categorical levels of experience
df_people['Experience'] = pd.cut(pd.to_numeric(df_people['YearsCodePro']), bins=bin_edges, labels=labels)

# print the resulting DataFrame
df_people.head(5)
# Out:
#           id                                             skills  \
# 20218  21170  [SQL, VBA, Microsoft SQL Server, Microsoft Azure]
# 38383  40624  [Java, SQL, MySQL, PostgreSQL, SQLite, AWS, , ...
# 67705  72374  [Python, Microsoft SQL Server, Google Cloud, ,...
# 17791  18627  [SQL, Microsoft SQL Server, PostgreSQL, , , , ...
# 40454  42833  [Python, SQL, Microsoft SQL Server, Microsoft ...
#
#                                              skills-want  YearsCodePro  \
# 20218    [Python, Microsoft SQL Server, Microsoft Azure]             0
# 38383    [Python, Microsoft SQL Server, Microsoft Azure]             0
# 67705       [Python, Microsoft SQL Server, Google Cloud]             0
# 17791         [Python, Microsoft SQL Server, PostgreSQL]            15
# 40454  [Python, SQL, Microsoft SQL Server, Microsoft ...             5
#
#        similarity_score_skills  similarity_score_interests Experience
# 20218                 0.599823                    1.000000     Junior
# 38383                 0.182016                    1.000000     Junior
# 67705                 0.539348                    0.795118     Junior
# 17791                 0.231775                    0.781387  Architect
# 40454                 0.777396                    0.777396  Associate

# %%
from scipy.spatial.distance import euclidean

# define a function to compute the similarity metric
def similarity(level1, level2):
    # define the vectors representing the levels of experience
    levels = {'Junior': [0, 0, 0, 0],
              'Associate': [1, 0, 0, 0],
              'Senior': [1, 1, 0, 0],
              'Architect': [1, 1, 1, 0]}
    
    # compute the Euclidean distance between the two vectors
    distance = euclidean(levels[level1], levels[level2])
    
    # return the similarity metric
    return 1 / (1 + distance)

# example usage of the similarity function
#print(similarity('Junior', 'Architect'))

# %%
# use function to compute the similarity based on level

df_people['similarity_score_experience'] = df_people["Experience"].apply(lambda x: similarity(role_experience, x))
df_people.head(5)
# Out:
#           id                                             skills  \
# 20218  21170  [SQL, VBA, Microsoft SQL Server, Microsoft Azure]
# 38383  40624  [Java, SQL, MySQL, PostgreSQL, SQLite, AWS, , ...
# 67705  72374  [Python, Microsoft SQL Server, Google Cloud, ,...
# 17791  18627  [SQL, Microsoft SQL Server, PostgreSQL, , , , ...
# 40454  42833  [Python, SQL, Microsoft SQL Server, Microsoft ...
#
#                                              skills-want  YearsCodePro  \
# 20218    [Python, Microsoft SQL Server, Microsoft Azure]             0
# 38383    [Python, Microsoft SQL Server, Microsoft Azure]             0
# 67705       [Python, Microsoft SQL Server, Google Cloud]             0
# 17791         [Python, Microsoft SQL Server, PostgreSQL]            15
# 40454  [Python, SQL, Microsoft SQL Server, Microsoft ...             5
#
#        similarity_score_skills  similarity_score_interests Experience  \
# 20218                 0.599823                    1.000000     Junior
# 38383                 0.182016                    1.000000     Junior
# 67705                 0.539348                    0.795118     Junior
# 17791                 0.231775                    0.781387  Architect
# 40454                 0.777396                    0.777396  Associate
#
#        similarity_score_experience
# 20218                     0.500000
# 38383                     0.500000
# 67705                     0.500000
# 17791                     0.414214
# 40454                     1.000000

# %%
# Calculate score based on the absolute difference between values
#df['similarity_score_experience'] = df["YearsCodePro"].apply(lambda x: abs(role_experience - int(x)))

# Normalize scores
#df['similarity_score_experience'] =  1 - scaler.fit_transform(df[['similarity_score_experience']])

#df

# %% [markdown]
# # Present Results from 3 Models

# %% [markdown]
# ## Model 1 - Compute Final Score

# %%
# Set weights
weight_skills = 0.8
weight_interests = 0
weight_experience = 0.2

# Calculate final score
df_people['score-model1'] = df_people['similarity_score_skills'] * weight_skills + df_people['similarity_score_interests'] * weight_interests + df_people['similarity_score_experience'] * weight_experience

# Get only final columns
#df = df[['id', 'skills', 'score']]

# Sort roles
df_people = df_people.sort_values(by=['score-model1'], ascending=False)

# See top 10 matches
df_people.head(10)
# Out:
#           id                                             skills  \
# 38615  40867    [Python, Microsoft SQL Server, Microsoft Azure]
# 40454  42833  [Python, SQL, Microsoft SQL Server, Microsoft ...
# 35947  38018       [SQL, Microsoft SQL Server, Microsoft Azure]
# 47114  49879         [R, Microsoft SQL Server, Microsoft Azure]
# 32645  34478  [Python, Microsoft SQL Server, SQLite, Microso...
# 34605  36569            [Python, MariaDB, Microsoft SQL Server]
# 882      921      [PowerShell, Python, SQLite, Microsoft Azure]
# 40169  42533                        [Python, , Microsoft Azure]
# 54738  58089  [Delphi, SQL, Microsoft SQL Server, Microsoft ...
# 48895  51782       [SQL, Microsoft SQL Server, Microsoft Azure]
#
#                                              skills-want  YearsCodePro  \
# 38615                     [Python, Microsoft SQL Server]             0
# 40454  [Python, SQL, Microsoft SQL Server, Microsoft ...             5
# 35947  [C#, Python, Microsoft SQL Server, Microsoft A...             7
# 47114         [R, Microsoft SQL Server, Microsoft Azure]             8
# 32645  [Python, Rust, Microsoft SQL Server, SQLite, M...             2
# 34605                                        [Java, SQL]             0
# 882                          [Python, , Microsoft Azure]             6
# 40169                                     [Python, Rust]             6
# 54738  [Delphi, SQL, Microsoft SQL Server, Microsoft ...             5
# 48895  [HTML/CSS, JavaScript, Python, Microsoft SQL S...             0
#
#        similarity_score_skills  similarity_score_interests Experience  \
# 38615                 1.000000                    0.736635     Junior
# 40454                 0.777396                    0.777396  Associate
# 35947                 0.734874                    0.776340  Associate
# 47114                 0.721383                    0.721383  Associate
# 32645                 0.812893                    0.708880     Junior
# 34605                 0.795268                    0.120943     Junior
# 882                   0.650398                    0.614464  Associate
# 40169                 0.614464                    0.525858  Associate
# 54738                 0.610931                    0.610931  Associate
# 48895                 0.734874                    0.606226     Junior
#
#        similarity_score_experience  score-model1
# 38615                          0.5      0.900000
# 40454                          1.0      0.821917
# 35947                          1.0      0.787899
# 47114                          1.0      0.777107
# 32645                          0.5      0.750315
# 34605                          0.5      0.736214
# 882                            1.0      0.720319
# 40169                          1.0      0.691572
# 54738                          1.0      0.688745
# 48895                          0.5      0.687899

# %% [markdown]
# ## Model 2 - Compute final score

# %%
# Set weights
weight_skills = 0.5
weight_interests = 0.3
weight_experience = 0.2

# Calculate final score
df_people['score-model2'] = df_people['similarity_score_skills'] * weight_skills + df_people['similarity_score_interests'] * weight_interests + df_people['similarity_score_experience'] * weight_experience

# Get only final columns
#df = df[['id', 'skills', 'score']]

# Sort roles
df_people = df_people.sort_values(by=['score-model2'], ascending=False)

# See top 10 matches
df_people.head(10)
# Out:
#           id                                             skills  \
# 40454  42833  [Python, SQL, Microsoft SQL Server, Microsoft ...
# 38615  40867    [Python, Microsoft SQL Server, Microsoft Azure]
# 35947  38018       [SQL, Microsoft SQL Server, Microsoft Azure]
# 47114  49879         [R, Microsoft SQL Server, Microsoft Azure]
# 32645  34478  [Python, Microsoft SQL Server, SQLite, Microso...
# 882      921      [PowerShell, Python, SQLite, Microsoft Azure]
# 20218  21170  [SQL, VBA, Microsoft SQL Server, Microsoft Azure]
# 54738  58089  [Delphi, SQL, Microsoft SQL Server, Microsoft ...
# 63272  67445       [SQL, Microsoft SQL Server, Microsoft Azure]
# 40169  42533                        [Python, , Microsoft Azure]
#
#                                              skills-want  YearsCodePro  \
# 40454  [Python, SQL, Microsoft SQL Server, Microsoft ...             5
# 38615                     [Python, Microsoft SQL Server]             0
# 35947  [C#, Python, Microsoft SQL Server, Microsoft A...             7
# 47114         [R, Microsoft SQL Server, Microsoft Azure]             8
# 32645  [Python, Rust, Microsoft SQL Server, SQLite, M...             2
# 882                          [Python, , Microsoft Azure]             6
# 20218    [Python, Microsoft SQL Server, Microsoft Azure]             0
# 54738  [Delphi, SQL, Microsoft SQL Server, Microsoft ...             5
# 63272       [SQL, Microsoft SQL Server, Microsoft Azure]             9
# 40169                                     [Python, Rust]             6
#
#        similarity_score_skills  similarity_score_interests Experience  \
# 40454                 0.777396                    0.777396  Associate
# 38615                 1.000000                    0.736635     Junior
# 35947                 0.734874                    0.776340  Associate
# 47114                 0.721383                    0.721383  Associate
# 32645                 0.812893                    0.708880     Junior
# 882                   0.650398                    0.614464  Associate
# 20218                 0.599823                    1.000000     Junior
# 54738                 0.610931                    0.610931  Associate
# 63272                 0.734874                    0.734874     Senior
# 40169                 0.614464                    0.525858  Associate
#
#        similarity_score_experience  score-model1  score-model2
# 40454                          1.0      0.821917      0.821917
# 38615                          0.5      0.900000      0.820990
# 35947                          1.0      0.787899      0.800339
# 47114                          1.0      0.777107      0.777107
# 32645                          0.5      0.750315      0.719111
# 882                            1.0      0.720319      0.709539
# 20218                          0.5      0.579859      0.699912
# 54738                          1.0      0.688745      0.688745
# 63272                          0.5      0.687899      0.687899
# 40169                          1.0      0.691572      0.664989

# %% [markdown]
# ## Model 3 - Compute Final Score

# %%
# Set weights
weight_skills = 0.4
weight_interests = 0.4
weight_experience = 0.2

# Calculate final score
df_people['score-model3'] = df_people['similarity_score_skills'] * weight_skills + df_people['similarity_score_interests'] * weight_interests + df_people['similarity_score_experience'] * weight_experience

# Get only final columns
#df = df[['id', 'skills', 'score']]

# Sort roles
df_people = df_people.sort_values(by=['score-model3'], ascending=False)

# See top 10 matches
df_people.head(10)
# Out:
#           id                                             skills  \
# 40454  42833  [Python, SQL, Microsoft SQL Server, Microsoft ...
# 35947  38018       [SQL, Microsoft SQL Server, Microsoft Azure]
# 38615  40867    [Python, Microsoft SQL Server, Microsoft Azure]
# 47114  49879         [R, Microsoft SQL Server, Microsoft Azure]
# 20218  21170  [SQL, VBA, Microsoft SQL Server, Microsoft Azure]
# 32645  34478  [Python, Microsoft SQL Server, SQLite, Microso...
# 882      921      [PowerShell, Python, SQLite, Microsoft Azure]
# 54738  58089  [Delphi, SQL, Microsoft SQL Server, Microsoft ...
# 63272  67445       [SQL, Microsoft SQL Server, Microsoft Azure]
# 7708    8070                [Python, SQL, Microsoft SQL Server]
#
#                                              skills-want  YearsCodePro  \
# 40454  [Python, SQL, Microsoft SQL Server, Microsoft ...             5
# 35947  [C#, Python, Microsoft SQL Server, Microsoft A...             7
# 38615                     [Python, Microsoft SQL Server]             0
# 47114         [R, Microsoft SQL Server, Microsoft Azure]             8
# 20218    [Python, Microsoft SQL Server, Microsoft Azure]             0
# 32645  [Python, Rust, Microsoft SQL Server, SQLite, M...             2
# 882                          [Python, , Microsoft Azure]             6
# 54738  [Delphi, SQL, Microsoft SQL Server, Microsoft ...             5
# 63272       [SQL, Microsoft SQL Server, Microsoft Azure]             9
# 7708                      [Python, Microsoft SQL Server]             3
#
#        similarity_score_skills  similarity_score_interests Experience  \
# 40454                 0.777396                    0.777396  Associate
# 35947                 0.734874                    0.776340  Associate
# 38615                 1.000000                    0.736635     Junior
# 47114                 0.721383                    0.721383  Associate
# 20218                 0.599823                    1.000000     Junior
# 32645                 0.812893                    0.708880     Junior
# 882                   0.650398                    0.614464  Associate
# 54738                 0.610931                    0.610931  Associate
# 63272                 0.734874                    0.734874     Senior
# 7708                  0.685608                    0.736635     Junior
#
#        similarity_score_experience  score-model1  score-model2  score-model3
# 40454                          1.0      0.821917      0.821917      0.821917
# 35947                          1.0      0.787899      0.800339      0.804486
# 38615                          0.5      0.900000      0.820990      0.794654
# 47114                          1.0      0.777107      0.777107      0.777107
# 20218                          0.5      0.579859      0.699912      0.739929
# 32645                          0.5      0.750315      0.719111      0.708709
# 882                            1.0      0.720319      0.709539      0.705945
# 54738                          1.0      0.688745      0.688745      0.688745
# 63272                          0.5      0.687899      0.687899      0.687899
# 7708                           0.5      0.648486      0.663794      0.668897

# %% [markdown]
# # See Results

# %% [markdown]
# ## Model 1

# %%
df_people = df_people[['id','skills','skills-want', 'Experience', 'score-model1', 'score-model2', 'score-model3']]
df_people = df_people.sort_values(by=['score-model1'], ascending=False)
df_people.head(3)
# Out:
#           id                                             skills  \
# 38615  40867    [Python, Microsoft SQL Server, Microsoft Azure]
# 40454  42833  [Python, SQL, Microsoft SQL Server, Microsoft ...
# 35947  38018       [SQL, Microsoft SQL Server, Microsoft Azure]
#
#                                              skills-want Experience  \
# 38615                     [Python, Microsoft SQL Server]     Junior
# 40454  [Python, SQL, Microsoft SQL Server, Microsoft ...  Associate
# 35947  [C#, Python, Microsoft SQL Server, Microsoft A...  Associate
#
#        score-model1  score-model2  score-model3
# 38615      0.900000      0.820990      0.794654
# 40454      0.821917      0.821917      0.821917
# 35947      0.787899      0.800339      0.804486

# %% [markdown]
# ## Model 2

# %%
df_people = df_people[['id','skills','skills-want', 'Experience', 'score-model1', 'score-model2', 'score-model3']]
df_people = df_people.sort_values(by=['score-model2'], ascending=False)
df_people.head(3)
# Out:
#           id                                             skills  \
# 40454  42833  [Python, SQL, Microsoft SQL Server, Microsoft ...
# 38615  40867    [Python, Microsoft SQL Server, Microsoft Azure]
# 35947  38018       [SQL, Microsoft SQL Server, Microsoft Azure]
#
#                                              skills-want Experience  \
# 40454  [Python, SQL, Microsoft SQL Server, Microsoft ...  Associate
# 38615                     [Python, Microsoft SQL Server]     Junior
# 35947  [C#, Python, Microsoft SQL Server, Microsoft A...  Associate
#
#        score-model1  score-model2  score-model3
# 40454      0.821917      0.821917      0.821917
# 38615      0.900000      0.820990      0.794654
# 35947      0.787899      0.800339      0.804486

# %% [markdown]
# ## Model 3

# %%
df_people = df_people[['id','skills','skills-want', 'Experience', 'score-model1', 'score-model2', 'score-model3']]
df_people = df_people.sort_values(by=['score-model3'], ascending=False)
df_people.head(3)
# Out:
#           id                                             skills  \
# 40454  42833  [Python, SQL, Microsoft SQL Server, Microsoft ...
# 35947  38018       [SQL, Microsoft SQL Server, Microsoft Azure]
# 38615  40867    [Python, Microsoft SQL Server, Microsoft Azure]
#
#                                              skills-want Experience  \
# 40454  [Python, SQL, Microsoft SQL Server, Microsoft ...  Associate
# 35947  [C#, Python, Microsoft SQL Server, Microsoft A...  Associate
# 38615                     [Python, Microsoft SQL Server]     Junior
#
#        score-model1  score-model2  score-model3
# 40454      0.821917      0.821917      0.821917
# 35947      0.787899      0.800339      0.804486
# 38615      0.900000      0.820990      0.794654

# %% [markdown]
# # Other Metrics

# %%
# For each matched person, show % of skills matched and % of interests matched


# Also show the % of skills matched and the % of skills not matched
# and for the matched skills, show the % that is only for skills and only for interests

# Define the list of skills to compare
skills_to_compare = role_skills

# Define a function to compute the percentage of skills that are mentioned in the list of skills and also in the DataFrame column skills
def compute_matching_percentage(row, column='skills'):
    matched_skills = set(row[column]) & set(skills_to_compare)
    return len(matched_skills) / len(skills_to_compare)

# Get matching skills
def compute_matching_list(row, column='skills'):
    matched_skills = set(row[column]) & set(skills_to_compare)
    return matched_skills

# Get non matching skills
def compute_non_matching_list(row, column='skills'):
    non_matched_skills = set(skills_to_compare) - set(row[column])
    return non_matched_skills

# Define a function to compute the percentage of skills that are not mentioned in the DataFrame column skills
def compute_non_matching_percentage(row, column='skills'):
    non_matched_skills = set(skills_to_compare) - set(row[column])
    return len(non_matched_skills) / len(skills_to_compare)

# Apply the functions to each row of the DataFrame
df_people['matching_percentage_skills'] = df_people.apply(lambda x: compute_matching_percentage(x,'skills'), axis=1)
df_people['non_matching_percentage_skills'] = df_people.apply(lambda x: compute_non_matching_percentage(x,'skills'), axis=1)

df_people['matching_percentage_interests'] = df_people.apply(lambda x: compute_matching_percentage(x,'skills-want'), axis=1)
df_people['non_matching_percentage_interests'] = df_people.apply(lambda x: compute_non_matching_percentage(x,'skills-want'), axis=1)

df_people['matching_list_skills'] = df_people.apply(lambda x: compute_matching_list(x,'skills'), axis=1)
df_people['non_matching_list_skills'] = df_people.apply(lambda x: compute_non_matching_list(x,'skills'), axis=1)

df_people['matching_list_interests'] = df_people.apply(lambda x: compute_matching_list(x,'skills-want'), axis=1)
df_people['non_matching_list_insterests'] = df_people.apply(lambda x: compute_non_matching_list(x,'skills-want'), axis=1)


# Print the resulting DataFrame
df_people
# Out:
#           id                                             skills  \
# 46618  49361  [C#, HTML/CSS, Python, SQL, Microsoft SQL Serv...
# 43159  45696  [Bash/Shell, HTML/CSS, JavaScript, PHP, Python...
# 33415  35298  [Go, HTML/CSS, JavaScript, PHP, TypeScript, Dy...
# 13469  14095        [C, Go, Java, Python, SQL, SQLite, , Flask]
# 63882  68104  [Bash/Shell, C, C#, F#, Java, JavaScript, OCam...
#
#                                              skills-want Experience  \
# 46618  [C#, HTML/CSS, Python, SQL, Microsoft SQL Serv...  Architect
# 43159  [Bash/Shell, Go, HTML/CSS, JavaScript, PHP, Py...  Architect
# 33415  [Elixir, Go, JavaScript, TypeScript, Elasticse...  Architect
# 13469  [C, Go, Java, Lua, Perl, Python, SQL, MySQL, P...     Junior
# 63882  [C#, Elixir, F#, Haskell, OCaml, PHP, Rust, SQ...     Senior
#
#        score-model1  score-model2  score-model3  matching_percentage_skills  \
# 46618      0.871817      0.875952      0.877330                    0.666667
# 43159      0.882843      0.864678      0.858623                    0.333333
# 33415      0.729396      0.692102      0.679671                    0.000000
# 13469      0.637075      0.611765      0.603329                    0.333333
# 63882      0.100000      0.100000      0.100000                    0.000000
#
#        non_matching_percentage_skills  matching_percentage_interests  \
# 46618                        0.333333                       0.666667
# 43159                        0.666667                       0.333333
# 33415                        1.000000                       0.000000
# 13469                        0.666667                       0.333333
# 63882                        1.000000                       0.000000
#
#        non_matching_percentage_interests            matching_list_skills  \
# 46618                           0.333333  {Microsoft SQL Server, Python}
# 43159                           0.666667                        {Python}
# 33415                           1.000000                              {}
# 13469                           0.666667                        {Python}
# 63882                           1.000000                              {}
#
#                               non_matching_list_skills  \
# 46618                                {Microsoft Azure}
# 43159          {Microsoft SQL Server, Microsoft Azure}
# 33415  {Microsoft SQL Server, Microsoft Azure, Python}
# 13469          {Microsoft SQL Server, Microsoft Azure}
# 63882  {Microsoft SQL Server, Microsoft Azure, Python}
#
#               matching_list_interests  \
# 46618  {Microsoft SQL Server, Python}
# 43159                        {Python}
# 33415                              {}
# 13469                        {Python}
# 63882                              {}
#
#                           non_matching_list_insterests
# 46618                                {Microsoft Azure}
# 43159          {Microsoft SQL Server, Microsoft Azure}
# 33415  {Microsoft SQL Server, Microsoft Azure, Python}
# 13469          {Microsoft SQL Server, Microsoft Azure}
# 63882  {Microsoft SQL Server, Microsoft Azure, Python}

# %%
list_skills = df_people[df_people['id']==22519]['skills']
print(list_skills.values)
# Out:
# []
