# %% [markdown]
# # Get Results generated from the Survey Part 1

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Results from Part 1 - For IT Professionals

# %%
df_results = pd.read_csv(filepath_or_buffer=f"../2-data/survey_people.csv", sep=",", encoding="latin1")

df_results.to_excel(f'part1_results_people.xlsx', index=False)
df_results
# Out:
#     id                                             skills  \
# 0    1  Java;JavaScript;Python;SQL;MySQL;SQLite;Node.j...
# 1    2  C++;HTML/CSS;Java;JavaScript;PHP;Python;TypeSc...
# 2    3  C++;HTML/CSS;Java;PHP;Python;SQL;MariaDB;MySQL...
# 3    4  HTML/CSS;JavaScript;Kotlin;TypeScript;AWS;Fire...
# 4    5  C#;Java;JavaScript;PHP;PowerShell;Python;R;SQL...
# 5    6  MATLAB;Python;R;SQL;Swift;Cassandra;CouchDB;Ma...
# 6    7  Bash/Shell;PowerShell;Python;Scala;SQL;MariaDB...
# 7    8  Bash/Shell;C#;C++;Java;PowerShell;Python;R;Sca...
# 8    9  Assembly;Bash/Shell;C#;C++;Go;HTML/CSS;Java;Ja...
# 9   10  MATLAB;Python;R;SQL;Microsoft SQL Server;Micro...
# 10  11  Python;SQL;Microsoft SQL Server;MySQL;Microsof...
# 11  12  Assembly;Bash/Shell;C;C#;C++;HTML/CSS;Java;Jav...
# 12  13  Python;SQL;Microsoft SQL Server;MySQL;Microsof...
# 13  14  Python;SQL;Microsoft SQL Server;MySQL;ASP.NET;...
# 14  15  Go;Java;JavaScript;MySQL;PostgreSQL;Google Clo...
# ...

# %% [markdown]
# # Results from Part 1 - For Roles

# %%
df_results = pd.read_csv(filepath_or_buffer=f"../2-data/survey_roles.csv", sep=",", encoding="latin1")

df_results.to_excel(f'part1_results_roles.xlsx', index=False)
df_results
# Out:
#     id                                             skills   explevel  \
# 0   11  Bash/Shell;PowerShell;Python;R;SQL;Microsoft S...     Senior
# 1   12  Bash/Shell;PowerShell;SQL;Microsoft SQL Server...  Associate
# 2   13  HTML/CSS;JavaScript;Python;SQL;MySQL;PostgreSQ...  Associate
# 3   14  Bash/Shell;PowerShell;SQL;Microsoft SQL Server...     Senior
# 4   15  Python;R;Scala;SQL;MongoDB;MySQL;AWS;Google Cl...     Senior
# 5   21  C#;Kotlin;Python;SQL;PostgreSQL;.NET;Apache Ka...  Associate
# 6   22  JavaScript;PostgreSQL;jQuery;React.js;React Na...  Associate
# 7   23  HTML/CSS;JavaScript;PostgreSQL;Angular.js;jQue...     Senior
# 8   24  C#;Kotlin;Python;Rust;Microsoft SQL Server;Pos...     Senior
# 9   25  C#;Java;JavaScript;Kotlin;Python;Rust;SQL;Mong...  Architect
# 10  31  Clojure;Go;Java;Python;Microsoft SQL Server;Mo...     Senior
# 11  32  Java;JavaScript;Objective-C;SQL;Swift;VBA;IBM ...     Senior
# 12  33  C#;Java;JavaScript;Objective-C;SQL;Swift;IBM D...     Senior
# ...
